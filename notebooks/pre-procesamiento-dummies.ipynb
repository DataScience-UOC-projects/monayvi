# %% [markdown]
# # Conversión de categóricas a numéricas

# %%
# %matplotlib inline

import numpy as np
import pandas as pd

# %%
import sys, os
sys.path.append(os.getcwd().replace('/notebooks',''))  # Replace with current directory name

# %%
from utils.data import Datasets
from utils.eda import column_explore

# %%
ds = Datasets()

# %%
ds.merge_tables()
ds.merged.head()
# Out:
#    cash_request_id  amount                 status  \
# 0              3.0     1.0               canceled
# 1              4.0   100.0             money_back
# 2              5.0   100.0               rejected
# 3              6.0   100.0  direct_debit_rejected
# 4              7.0   100.0               rejected
#
#                         created_at                       updated_at  user_id  \
# 0 2019-11-19 13:57:53.511561+00:00 2020-12-14 10:25:57.710844+00:00     47.0
# 1 2019-12-09 14:47:35.190714+00:00 2020-11-04 12:54:52.120014+00:00      NaN
# 2 2019-12-10 19:05:21.596873+00:00 2019-12-11 16:47:42.407830+00:00    804.0
# 3 2019-12-10 19:05:48.921042+00:00 2020-12-18 22:47:47.993817+00:00    812.0
# 4 2019-12-10 19:13:35.825460+00:00 2019-12-11 09:46:59.779773+00:00    191.0
#
#                       moderated_at  deleted_account_id  \
# 0        2019-11-20 12:16:50+00:00                 NaN
# 1        2019-12-09 14:58:28+00:00              1309.0
# 2 2019-12-11 16:47:42.405646+00:00                 NaN
# 3        2019-12-11 09:40:33+00:00                 NaN
# 4 2019-12-11 09:46:59.777728+00:00                 NaN
#
#                 reimbursement_date cash_request_received_date  ... fee_status  \
# 0        2019-12-05 23:00:00+00:00                        NaT  ...        NaN
# 1        2019-12-16 23:00:00+00:00                        NaT  ...        NaN
# 2 2020-01-09 19:05:21.596363+00:00                        NaT  ...        NaN
# 3        2020-02-05 23:00:00+00:00                 2019-12-11  ...        NaN
# 4 2020-01-09 19:13:35.825041+00:00                        NaT  ...        NaN
#
#   fee_category fee_total_amount fee_reason fee_created_at fee_updated_at  \
# 0          NaN              NaN        NaN            NaT            NaT
# 1          NaN              NaN        NaN            NaT            NaT
# 2          NaN              NaN        NaN            NaT            NaT
# 3          NaN              NaN        NaN            NaT            NaT
# 4          NaN              NaN        NaN            NaT            NaT
#
#    fee_paid_at  fee_from_date  fee_to_date fee_charge_moment
# 0          NaT            NaT          NaT               NaN
# 1          NaT            NaT          NaT               NaN
# 2          NaT            NaT          NaT               NaN
# 3          NaT            NaT          NaT               NaN
# 4          NaT            NaT          NaT               NaN
#
# [5 rows x 30 columns]

# %%
merged_dummies = ds.get_dummies_and_drop_cols()
merged_dummies
# Out:
#        cash_request_id  amount                       created_at  \
# 0                  3.0     1.0 2019-11-19 13:57:53.511561+00:00
# 1                  4.0   100.0 2019-12-09 14:47:35.190714+00:00
# 2                  5.0   100.0 2019-12-10 19:05:21.596873+00:00
# 3                  6.0   100.0 2019-12-10 19:05:48.921042+00:00
# 4                  7.0   100.0 2019-12-10 19:13:35.825460+00:00
# ...                ...     ...                              ...
# 32093          27006.0    50.0 2020-11-01 23:07:55.231487+00:00
# 32094          27007.0   100.0 2020-11-01 23:11:37.788849+00:00
# 32095          27008.0    50.0 2020-11-01 23:13:19.286745+00:00
# 32096          27009.0    60.0 2020-11-01 23:15:28.102894+00:00
# 32097          27010.0   100.0 2020-11-01 23:42:30.847066+00:00
#
#                             updated_at   user_id  \
# 0     2020-12-14 10:25:57.710844+00:00      47.0
# 1     2020-11-04 12:54:52.120014+00:00       NaN
# 2     2019-12-11 16:47:42.407830+00:00     804.0
# 3     2020-12-18 22:47:47.993817+00:00     812.0
# 4     2019-12-11 09:46:59.779773+00:00     191.0
# ...                                ...       ...
# 32093 2020-12-18 13:11:35.051472+00:00   55916.0
# 32094 2020-12-18 13:13:10.258884+00:00   39339.0
# 32095 2020-11-02 09:06:37.169489+00:00   24505.0
# 32096 2020-12-18 13:10:18.004190+00:00  100781.0
# 32097 2020-12-18 13:10:37.690636+00:00   96599.0
#
#                           moderated_at  deleted_account_id  \
# 0            2019-11-20 12:16:50+00:00                 NaN
# 1            2019-12-09 14:58:28+00:00              1309.0
# 2     2019-12-11 16:47:42.405646+00:00                 NaN
# 3            2019-12-11 09:40:33+00:00                 NaN
# 4     2019-12-11 09:46:59.777728+00:00                 NaN
# ...                                ...                 ...
# 32093                              NaT                 NaN
# 32094                              NaT                 NaN
# 32095 2020-11-02 09:06:37.162733+00:00                 NaN
# 32096                              NaT                 NaN
# 32097                              NaT                 NaN
#
#                     reimbursement_date cash_request_received_date  \
# 0            2019-12-05 23:00:00+00:00                        NaT
# 1            2019-12-16 23:00:00+00:00                        NaT
# 2     2020-01-09 19:05:21.596363+00:00                        NaT
# 3            2020-02-05 23:00:00+00:00                 2019-12-11
# 4     2020-01-09 19:13:35.825041+00:00                        NaT
# ...                                ...                        ...
# 32093        2020-11-12 22:00:00+00:00                 2020-11-02
# 32094        2020-11-29 11:00:00+00:00                 2020-11-02
# 32095        2020-11-24 23:51:00+00:00                        NaT
# 32096        2020-12-04 11:00:00+00:00                        NaT
# 32097        2020-11-30 23:00:00+00:00                 2020-11-03
#
#                        money_back_date  ... crecostatus_pending  \
# 0                                  NaT  ...                   0
# 1                                  NaT  ...                   0
# 2                                  NaT  ...                   0
# 3                                  NaT  ...                   1
# 4                                  NaT  ...                   0
# ...                                ...  ...                 ...
# 32093 2020-11-12 19:39:20.241980+00:00  ...                   0
# 32094 2020-11-29 19:27:43.055298+00:00  ...                   0
# 32095                              NaT  ...                   0
# 32096 2020-12-02 14:17:37.433540+00:00  ...                   0
# 32097 2020-11-30 09:17:45.747387+00:00  ...                   0
#
#       crecostatus_pending_direct_debit ftype_instant_payment  ftype_postpone  \
# 0                                    0                     0               0
# 1                                    0                     0               0
# 2                                    0                     0               0
# 3                                    0                     0               0
# 4                                    0                     0               0
# ...                                ...                   ...             ...
# 32093                                0                     1               0
# 32094                                0                     1               0
# 32095                                0                     0               0
# 32096                                0                     1               0
# 32097                                0                     1               0
#
#        fstatus_cancelled  fstatus_confirmed  fstatus_rejected  \
# 0                      0                  0                 0
# 1                      0                  0                 0
# 2                      0                  0                 0
# 3                      0                  0                 0
# 4                      0                  0                 0
# ...                  ...                ...               ...
# 32093                  0                  0                 0
# 32094                  0                  0                 0
# 32095                  0                  0                 0
# 32096                  0                  0                 0
# 32097                  0                  0                 0
#
#       fcategory_ninguna fcategory_rejected_direct_debit fchargemoment_before
# 0                     1                               0                    0
# 1                     1                               0                    0
# 2                     1                               0                    0
# 3                     1                               0                    0
# 4                     1                               0                    0
# ...                 ...                             ...                  ...
# 32093                 1                               0                    0
# 32094                 1                               0                    0
# 32095                 1                               0                    0
# 32096                 1                               0                    0
# 32097                 1                               0                    0
#
# [32094 rows x 44 columns]

# %%
merged_dummies.drop(columns=['cash_request_id','user_id','deleted_account_id','id_usuario','updated_at','moderated_at','cash_request_received_date','send_at','reco_creation','reco_last_update',
                              'fee_id','fee_cash_request_id','fee_reason','fee_created_at','fee_updated_at','fee_paid_at','fee_from_date','fee_to_date'], inplace=True)
merged_dummies.columns
# Out:
# Index(['amount', 'created_at', 'reimbursement_date', 'money_back_date',
#        'fee_total_amount', 'created_dayofweek', 'created_hour',
#        'created_year_month_dummy', 'cstatus_canceled',
#        'cstatus_direct_debit_rejected', 'cstatus_direct_debit_sent',
#        'cstatus_money_back', 'cstatus_rejected',
#        'cstatus_transaction_declined', 'ctranstype_regular',
#        'crecostatus_completed', 'crecostatus_pending',
#        'crecostatus_pending_direct_debit', 'ftype_instant_payment',
#        'ftype_postpone', 'fstatus_cancelled', 'fstatus_confirmed',
#        'fstatus_rejected', 'fcategory_ninguna',
#        'fcategory_rejected_direct_debit', 'fchargemoment_before'],
#       dtype='object')

# %%
numericals = merged_dummies.select_dtypes(np.number)
corr = numericals.corr()
display(corr)
# Create a heatmap to visualize the correlation matrix
import seaborn as sns
sns.set_context("poster") # Set the Seaborn context to "poster" for larger text and figures
sns.set(rc={"figure.figsize": (12., 6.)}) # Set the default figure size for Seaborn plots
sns.set_style("whitegrid") # Set the Seaborn style to "whitegrid" for a white background with gridlines
sns.heatmap(corr.round(2), annot=True)
# Out:
#                                     amount  fee_total_amount  \
# amount                            1.000000         -0.008142
# fee_total_amount                 -0.008142          1.000000
# created_dayofweek                -0.036137         -0.002958
# created_hour                     -0.011089          0.000508
# created_year_month_dummy          0.158043         -0.007901
# cstatus_canceled                 -0.007366         -0.000116
# cstatus_direct_debit_rejected    -0.020927         -0.002144
# cstatus_direct_debit_sent         0.013288         -0.000404
# cstatus_money_back                0.009508          0.002317
# cstatus_rejected                 -0.001299               NaN
# cstatus_transaction_declined      0.002995         -0.000329
# ctranstype_regular                0.234897         -0.003522
# crecostatus_completed            -0.031921         -0.003818
# crecostatus_pending              -0.023238         -0.002179
# crecostatus_pending_direct_debit  0.003716         -0.000277
# ftype_instant_payment            -0.172468          0.006530
# ftype_postpone                    0.076264         -0.005268
# fstatus_cancelled                 0.031927         -0.003812
# fstatus_confirmed                 0.012781         -0.000446
# fstatus_rejected                 -0.044519         -0.001690
# fcategory_ninguna                -0.026654          0.002352
# fcategory_rejected_direct_debit   0.011076         -0.001976
# fchargemoment_before              0.045567         -0.003510
#
#                                   created_dayofweek  created_hour  \
# amount                                    -0.036137     -0.011089
# fee_total_amount                          -0.002958      0.000508
# created_dayofweek                          1.000000     -0.032771
# created_hour                              -0.032771      1.000000
# created_year_month_dummy                  -0.055969     -0.019662
# cstatus_canceled                           0.001441      0.006143
# cstatus_direct_debit_rejected             -0.001822      0.012336
# cstatus_direct_debit_sent                  0.013355      0.000126
# cstatus_money_back                         0.034377     -0.005284
# cstatus_rejected                          -0.039888     -0.002726
# cstatus_transaction_declined              -0.009236      0.003346
# ctranstype_regular                        -0.025465      0.037598
# crecostatus_completed                      0.026095     -0.005657
# crecostatus_pending                       -0.003716      0.011328
# crecostatus_pending_direct_debit           0.017331      0.004000
# ftype_instant_payment                      0.030769     -0.016289
# ftype_postpone                             0.002211      0.005825
# fstatus_cancelled                          0.006249      0.013388
# fstatus_confirmed                         -0.008114      0.004627
# fstatus_rejected                           0.003052      0.004712
# fcategory_ninguna                          0.002122     -0.005484
# fcategory_rejected_direct_debit            0.000597      0.001096
# fchargemoment_before                       0.006147     -0.005596
#
#                                   created_year_month_dummy  cstatus_canceled  \
# amount                                            0.158043         -0.007366
# fee_total_amount                                 -0.007901         -0.000116
# created_dayofweek                                -0.055969          0.001441
# created_hour                                     -0.019662          0.006143
# created_year_month_dummy                          1.000000          0.005255
# cstatus_canceled                                  0.005255          1.000000
# cstatus_direct_debit_rejected                     0.024825         -0.008383
# cstatus_direct_debit_sent                        -0.010722         -0.001588
# cstatus_money_back                               -0.191897         -0.053657
# cstatus_rejected                                  0.203705         -0.016760
# cstatus_transaction_declined                     -0.052540         -0.001279
# ctranstype_regular                                0.172118          0.015953
# crecostatus_completed                             0.066541         -0.014474
# crecostatus_pending                               0.026714         -0.008509
# crecostatus_pending_direct_debit                  0.009716         -0.001107
# ftype_instant_payment                            -0.351400         -0.016077
# ftype_postpone                                    0.106987         -0.018668
# fstatus_cancelled                                 0.063847         -0.011466
# fstatus_confirmed                                -0.040362          0.034374
# fstatus_rejected                                 -0.010487          0.008469
# fcategory_ninguna                                -0.154882          0.001476
# fcategory_rejected_direct_debit                   0.140691          0.001112
# fchargemoment_before                             -0.046534         -0.013061
#
#                                   cstatus_direct_debit_rejected  \
# amount                                                -0.020927
# fee_total_amount                                      -0.002144
# created_dayofweek                                     -0.001822
# created_hour                                           0.012336
# created_year_month_dummy                               0.024825
# cstatus_canceled                                      -0.008383
# cstatus_direct_debit_rejected                          1.000000
# cstatus_direct_debit_sent                             -0.012197
# cstatus_money_back                                    -0.412015
# cstatus_rejected                                      -0.128698
# cstatus_transaction_declined                          -0.009819
# ctranstype_regular                                    -0.010008
# crecostatus_completed                                 -0.104383
# crecostatus_pending                                    0.964659
# crecostatus_pending_direct_debit                      -0.008502
# ftype_instant_payment                                 -0.022540
# ftype_postpone                                         0.049847
# fstatus_cancelled                                      0.092265
# fstatus_confirmed                                      0.029191
# fstatus_rejected                                       0.620067
# fcategory_ninguna                                     -0.260519
# fcategory_rejected_direct_debit                        0.134749
# fchargemoment_before                                   0.005240
#
#                                   cstatus_direct_debit_sent  \
# amount                                             0.013288
# fee_total_amount                                  -0.000404
# created_dayofweek                                  0.013355
# created_hour                                       0.000126
# created_year_month_dummy                          -0.010722
# cstatus_canceled                                  -0.001588
# cstatus_direct_debit_rejected                     -0.012197
# cstatus_direct_debit_sent                          1.000000
# cstatus_money_back                                -0.078068
# cstatus_rejected                                  -0.024385
# cstatus_transaction_declined                      -0.001861
# ctranstype_regular                                -0.024032
# crecostatus_completed                             -0.021059
# crecostatus_pending                               -0.012380
# crecostatus_pending_direct_debit                   0.697072
# ftype_instant_payment                              0.004669
# ftype_postpone                                     0.018344
# fstatus_cancelled                                  0.024537
# fstatus_confirmed                                 -0.002521
# fstatus_rejected                                   0.038606
# fcategory_ninguna                                 -0.020422
# fcategory_rejected_direct_debit                    0.015864
# fchargemoment_before                               0.011402
#
#                                   cstatus_money_back  cstatus_rejected  ...  \
# amount                                      0.009508         -0.001299  ...
# fee_total_amount                            0.002317               NaN  ...
# created_dayofweek                           0.034377         -0.039888  ...
# created_hour                               -0.005284         -0.002726  ...
# created_year_month_dummy                   -0.191897          0.203705  ...
# cstatus_canceled                           -0.053657         -0.016760  ...
# cstatus_direct_debit_rejected              -0.412015         -0.128698  ...
# cstatus_direct_debit_sent                  -0.078068         -0.024385  ...
# cstatus_money_back                          1.000000         -0.823741  ...
# cstatus_rejected                           -0.823741          1.000000  ...
# cstatus_transaction_declined               -0.062849         -0.019632  ...
# ctranstype_regular                         -0.172487          0.200237  ...
# crecostatus_completed                       0.266141         -0.222203  ...
# crecostatus_pending                        -0.418193         -0.130628  ...
# crecostatus_pending_direct_debit           -0.054419         -0.016998  ...
# ftype_instant_payment                       0.343281         -0.368714  ...
# ftype_postpone                              0.228808         -0.286596  ...
# fstatus_cancelled                           0.138252         -0.216202  ...
# fstatus_confirmed                          -0.083817         -0.026598  ...
# fstatus_rejected                           -0.261696         -0.099712  ...
# fcategory_ninguna                           0.025769          0.137474  ...
# fcategory_rejected_direct_debit             0.029390         -0.116154  ...
# fchargemoment_before                        0.176457         -0.200509  ...
#
#                                   crecostatus_pending  \
# amount                                      -0.023238
# fee_total_amount                            -0.002179
# created_dayofweek                           -0.003716
# created_hour                                 0.011328
# created_year_month_dummy                     0.026714
# cstatus_canceled                            -0.008509
# cstatus_direct_debit_rejected                0.964659
# cstatus_direct_debit_sent                   -0.012380
# cstatus_money_back                          -0.418193
# cstatus_rejected                            -0.130628
# cstatus_transaction_declined                -0.009967
# ctranstype_regular                          -0.001056
# crecostatus_completed                       -0.112807
# crecostatus_pending                          1.000000
# crecostatus_pending_direct_debit            -0.008630
# ftype_instant_payment                       -0.026863
# ftype_postpone                               0.048204
# fstatus_cancelled                            0.094124
# fstatus_confirmed                            0.030908
# fstatus_rejected                             0.641304
# fcategory_ninguna                           -0.277701
# fcategory_rejected_direct_debit              0.140271
# fchargemoment_before                         0.001612
#
#                                   crecostatus_pending_direct_debit  \
# amount                                                    0.003716
# fee_total_amount                                         -0.000277
# created_dayofweek                                         0.017331
# created_hour                                              0.004000
# created_year_month_dummy                                  0.009716
# cstatus_canceled                                         -0.001107
# cstatus_direct_debit_rejected                            -0.008502
# cstatus_direct_debit_sent                                 0.697072
# cstatus_money_back                                       -0.054419
# cstatus_rejected                                         -0.016998
# cstatus_transaction_declined                             -0.001297
# ctranstype_regular                                       -0.009797
# crecostatus_completed                                    -0.014679
# crecostatus_pending                                      -0.008630
# crecostatus_pending_direct_debit                          1.000000
# ftype_instant_payment                                    -0.000872
# ftype_postpone                                            0.000628
# fstatus_cancelled                                         0.008943
# fstatus_confirmed                                        -0.001757
# fstatus_rejected                                          0.027841
# fcategory_ninguna                                        -0.038848
# fcategory_rejected_direct_debit                           0.030831
# fchargemoment_before                                     -0.010523
#
#                                   ftype_instant_payment  ftype_postpone  \
# amount                                        -0.172468        0.076264
# fee_total_amount                               0.006530       -0.005268
# created_dayofweek                              0.030769        0.002211
# created_hour                                  -0.016289        0.005825
# created_year_month_dummy                      -0.351400        0.106987
# cstatus_canceled                              -0.016077       -0.018668
# cstatus_direct_debit_rejected                 -0.022540        0.049847
# cstatus_direct_debit_sent                      0.004669        0.018344
# cstatus_money_back                             0.343281        0.228808
# cstatus_rejected                              -0.368714       -0.286596
# cstatus_transaction_declined                   0.053244       -0.021866
# ctranstype_regular                            -0.583675       -0.000500
# crecostatus_completed                         -0.038013        0.122870
# crecostatus_pending                           -0.026863        0.048204
# crecostatus_pending_direct_debit              -0.000872        0.000628
# ftype_instant_payment                          1.000000       -0.410686
# ftype_postpone                                -0.410686        1.000000
# fstatus_cancelled                             -0.299459        0.723316
# fstatus_confirmed                              0.048333       -0.029626
# fstatus_rejected                               0.090082       -0.110678
# fcategory_ninguna                              0.196997        0.153123
# fcategory_rejected_direct_debit               -0.166446       -0.129377
# fchargemoment_before                          -0.287325        0.699621
#
#                                   fstatus_cancelled  fstatus_confirmed  \
# amount                                     0.031927           0.012781
# fee_total_amount                          -0.003812          -0.000446
# created_dayofweek                          0.006249          -0.008114
# created_hour                               0.013388           0.004627
# created_year_month_dummy                   0.063847          -0.040362
# cstatus_canceled                          -0.011466           0.034374
# cstatus_direct_debit_rejected              0.092265           0.029191
# cstatus_direct_debit_sent                  0.024537          -0.002521
# cstatus_money_back                         0.138252          -0.083817
# cstatus_rejected                          -0.216202          -0.026598
# cstatus_transaction_declined              -0.014260           0.707250
# ctranstype_regular                        -0.010612          -0.025091
# crecostatus_completed                      0.150814          -0.021348
# crecostatus_pending                        0.094124           0.030908
# crecostatus_pending_direct_debit           0.008943          -0.001757
# ftype_instant_payment                     -0.299459           0.048333
# ftype_postpone                             0.723316          -0.029626
# fstatus_cancelled                          1.000000          -0.022349
# fstatus_confirmed                         -0.022349           1.000000
# fstatus_rejected                          -0.083783          -0.010307
# fcategory_ninguna                          0.082324          -0.030631
# fcategory_rejected_direct_debit           -0.086879           0.012640
# fchargemoment_before                       0.173404          -0.020727
#
#                                   fstatus_rejected  fcategory_ninguna  \
# amount                                   -0.044519          -0.026654
# fee_total_amount                         -0.001690           0.002352
# created_dayofweek                         0.003052           0.002122
# created_hour                              0.004712          -0.005484
# created_year_month_dummy                 -0.010487          -0.154882
# cstatus_canceled                          0.008469           0.001476
# cstatus_direct_debit_rejected             0.620067          -0.260519
# cstatus_direct_debit_sent                 0.038606          -0.020422
# cstatus_money_back                       -0.261696           0.025769
# cstatus_rejected                         -0.099712           0.137474
# cstatus_transaction_declined             -0.007608           0.010489
# ctranstype_regular                       -0.049550          -0.112061
# crecostatus_completed                    -0.016677          -0.385308
# crecostatus_pending                       0.641304          -0.277701
# crecostatus_pending_direct_debit          0.027841          -0.038848
# ftype_instant_payment                     0.090082           0.196997
# ftype_postpone                           -0.110678           0.153123
# fstatus_cancelled                        -0.083783           0.082324
# fstatus_confirmed                        -0.010307          -0.030631
# fstatus_rejected                          1.000000          -0.285811
# fcategory_ninguna                        -0.285811           1.000000
# fcategory_rejected_direct_debit           0.166097          -0.844918
# fchargemoment_before                     -0.077220           0.107128
#
#                                   fcategory_rejected_direct_debit  \
# amount                                                   0.011076
# fee_total_amount                                        -0.001976
# created_dayofweek                                        0.000597
# created_hour                                             0.001096
# created_year_month_dummy                                 0.140691
# cstatus_canceled                                         0.001112
# cstatus_direct_debit_rejected                            0.134749
# cstatus_direct_debit_sent                                0.015864
# cstatus_money_back                                       0.029390
# cstatus_rejected                                        -0.116154
# cstatus_transaction_declined                            -0.008862
# ctranstype_regular                                       0.051005
# crecostatus_completed                                    0.387531
# crecostatus_pending                                      0.140271
# crecostatus_pending_direct_debit                         0.030831
# ftype_instant_payment                                   -0.166446
# ftype_postpone                                          -0.129377
# fstatus_cancelled                                       -0.086879
# fstatus_confirmed                                        0.012640
# fstatus_rejected                                         0.166097
# fcategory_ninguna                                       -0.844918
# fcategory_rejected_direct_debit                          1.000000
# fchargemoment_before                                    -0.090515
#
#                                   fchargemoment_before
# amount                                        0.045567
# fee_total_amount                             -0.003510
# created_dayofweek                             0.006147
# created_hour                                 -0.005596
# created_year_month_dummy                     -0.046534
# cstatus_canceled                             -0.013061
# cstatus_direct_debit_rejected                 0.005240
# cstatus_direct_debit_sent                     0.011402
# cstatus_money_back                            0.176457
# cstatus_rejected                             -0.200509
# cstatus_transaction_declined                 -0.015298
# ctranstype_regular                           -0.062427
# crecostatus_completed                         0.011596
# crecostatus_pending                           0.001612
# crecostatus_pending_direct_debit             -0.010523
# ftype_instant_payment                        -0.287325
# ftype_postpone                                0.699621
# fstatus_cancelled                             0.173404
# fstatus_confirmed                            -0.020727
# fstatus_rejected                             -0.077220
# fcategory_ninguna                             0.107128
# fcategory_rejected_direct_debit              -0.090515
# fchargemoment_before                          1.000000
#
# [23 rows x 23 columns]
# <Axes: >
